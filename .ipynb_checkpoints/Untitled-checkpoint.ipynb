# %%
import numpy

from pyscf import qmmm
from pyscf import gto, scf

#     from scipy.linalg import sqrtm

#     ovlp = mf.get_ovlp()
#     mo   = mf.mo_coeff
#     nmo  = len(mf.mo_occ)

#     ww = numpy.einsum("mp,mn->pn", mo, sqrtm(ovlp))
#     w2 = ww ** 2
    
#     ni_3d_idx = mol.search_ao_label("Ni 3d")
#     tmp = numpy.einsum("pn->p", w2[:,ni_3d_idx])
#     mo_list = numpy.sort(tmp.argsort()[::-1][:5])

#     ncas = len(mo_list)
#     nele = int(sum(mf.mo_occ[mo_list]))
    
#     print(ncas)
#     print(nele)
    
#     mycas = mf.CASSCF(ncas, nele)
#     mycas.verbose = 0
# #     mycas.fcisolver.nroots = 5
#     mo = mycas.sort_mo(mo_list)
#     mycas.kernel(mo)
#     e_cas_list.append(mycas.e_tot)

def get_r_ene(r):
    dr_list = numpy.linspace(-0.05, 0.05, 21)

    atm_list   = []
    e_r_list   = []
    e_u0_list  = []
    e_u1_list  = []

    dm0_rhf  = None
    dm0_u0hf = None
    dm0_u1hf = None

    for dr in dr_list:
        rz  = r + dr
        rxy = r - dr
        atoms = f'''
          Ni    0.0000000     0.0000000     0.0000000
          H     0.0000000     0.0000000    {rz: 10.7f}
          H     0.0000000    {rxy: 10.7f}     0.0000000
          H    {rxy: 10.7f}     0.0000000     0.0000000
          H     0.0000000     0.0000000    {-rz: 10.7f}
          H     0.0000000    {-rxy: 10.7f}     0.0000000
          H    {-rxy: 10.7f}     0.0000000     0.0000000
        '''
        atm_list.append(atoms)

        mol = gto.Mole()
        mol.verbose = 0
        mol.output = f"./{dr}-0.log"
        mol.atom = atoms
        mol.basis = {"H": "sto3g", 'Ni': "lanl2dz"}
        mol.ecp   = {'Ni': "lanl2dz"}
        mol.symmetry = 0
        mol.charge   = -4
        mol.build()

        mf = scf.RHF(mol)
        mf.max_cycle  = 1000
        mf.diis_space = 10
        mf.verbose    = 4
        mf.kernel(dm0 = dm0_rhf)
        dm0_rhf = mf.make_rdm1()    
        e_r_list.append(mf.e_tot)

        assert mf.converged

        mf = scf.UHF(mol)
        mf.max_cycle  = 1000
        mf.diis_space = 10
        mf.verbose    = 4
        mf.kernel(dm0 = dm0_u0hf)
        dm0_u0hf = mf.make_rdm1()    
        e_u0_list.append(mf.e_tot)

        assert mf.converged

        mol = gto.Mole()
        mol.verbose = 0
        mol.output = f"./{dr}-1.log"
        mol.atom = atoms
        mol.basis = {"H": "sto3g", 'Ni': "lanl2dz"}
        mol.ecp   = {'Ni': "lanl2dz"}
        mol.symmetry = 0
        mol.charge   = -4
        mol.spin = 2
        mol.build()

        mf = scf.UHF(mol)
        mf.max_cycle  = 1000
        mf.diis_space = 10
        mf.verbose    = 4
        mf.kernel(dm0 = dm0_u1hf)
        dm0_u1hf = mf.make_rdm1()    
        e_u1_list.append(mf.e_tot)

        assert mf.converged
        
        print(f"dr = {dr: 4.2f}, erhf = {e_r_list[-1]: 8.6f}, eu0hf = {e_u0_list[-1]: 8.6f}, eu1hf = {e_u1_list[-1]: 8.6f}")
    
    e_r_list  = numpy.asarray(e_r_list)
    e_u0_list = numpy.asarray(e_u0_list)
    e_u1_list = numpy.asarray(e_u1_list)
    
    return dr_list, e_r_list, e_u0_list, e_u1_list

# %%
dr_list, e_r_list, e_u0_list, e_u1_list = get_r_ene(1.6)
# Out:
# WARN: HOMO 0.55273844130176 == LUMO 0.552738441301762
# WARN: HOMO 0.518917624580312 == LUMO 0.51906814524167
# WARN: HOMO 0.472111939088637 == LUMO 0.472860542837774
# WARN: HOMO 0.510118232105099 == LUMO 0.510763761536464
# WARN: HOMO 0.508782622004847 == LUMO 0.509333816183584
# WARN: HOMO 0.466040534480158 == LUMO 0.466443222515037
# WARN: HOMO 0.467818781869132 == LUMO 0.468041035552779
# WARN: HOMO 0.467708444099341 == LUMO 0.468165026344459
# WARN: HOMO 0.46587496287718 == LUMO 0.466775902143403
# WARN: HOMO 0.467571405510702 == LUMO 0.46854273049982
# WARN: HOMO 0.467113759316613 == LUMO 0.467935094887959
# WARN: HOMO 0.46654865611388 == LUMO 0.467408838397377
# WARN: HOMO 0.466793214345824 == LUMO 0.46764125276244
# WARN: HOMO 0.465963835192887 == LUMO 0.466492375144028
# WARN: HOMO 0.46621137173326 == LUMO 0.466951231080111
# WARN: HOMO 0.46708142346795 == LUMO 0.467262695172103
# WARN: HOMO 0.466497349476548 == LUMO 0.466593003465194
# WARN: HOMO 0.466622226208636 == LUMO 0.466816977561464
# WARN: HOMO 0.466809306847744 == LUMO 0.466900648046692
# WARN: HOMO 0.466376468401312 == LUMO 0.467145292584512
# WARN: HOMO 0.466594482192384 == LUMO 0.467333658108529
# WARN: HOMO 0.465923396716153 == LUMO 0.466708301726748
# WARN: HOMO 0.464075671777241 == LUMO 0.464440652605288
# WARN: HOMO 0.46546029958103 == LUMO 0.465886206030268
# WARN: HOMO 0.465493995380237 == LUMO 0.465729687633491
# WARN: HOMO 0.465026039609815 == LUMO 0.465626786006234
# WARN: HOMO 0.465478064044146 == LUMO 0.465944280013451
# WARN: HOMO 0.466001301115095 == LUMO 0.466355943863455
# WARN: HOMO 0.466081478312658 == LUMO 0.46634578904383
# WARN: HOMO 0.466162068301016 == LUMO 0.466494242646455
# WARN: HOMO 0.466355607855828 == LUMO 0.466619901470506
# WARN: HOMO 0.466538086804855 == LUMO 0.466599843999599
# WARN: HOMO 0.466436274918243 == LUMO 0.466833701770205
# WARN: HOMO 0.466382441526057 == LUMO 0.466632080515212
# WARN: HOMO 0.465469948925322 == LUMO 0.465963243742045
# WARN: HOMO 0.466162560019686 == LUMO 0.466371989917565
# WARN: HOMO 0.465910693883372 == LUMO 0.466140456085701
# WARN: HOMO 0.465514071270945 == LUMO 0.465685689502088
# WARN: HOMO 0.465751968573738 == LUMO 0.465877398431977
# WARN: HOMO 0.466230901774767 == LUMO 0.46636318173458
# WARN: HOMO 0.466065664907317 == LUMO 0.466150388412886
# WARN: HOMO 0.466289542517688 == LUMO 0.466330201963792
# WARN: HOMO 0.466271079373173 == LUMO 0.46643162452902
# WARN: HOMO 0.466542492178678 == LUMO 0.466560779327053
# WARN: HOMO 0.466183835934556 == LUMO 0.46650356638974
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-fe42d1dc821a>", line 1, in <module>
#     dr_list, e_r_list, e_u0_list, e_u1_list = get_r_ene(1.6)
#   File "<ipython-input-1-a0a1ae08209f>", line 73, in get_r_ene
#     mf.kernel(dm0 = dm0_rhf)
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/lib/misc.py", line 638, in aliased_fn
#     return getattr(self, fname)(*args, **kwargs)
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/scf/hf.py", line 1669, in scf
#     kernel(self, self.conv_tol, self.conv_tol_grad,
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/scf/hf.py", line 178, in kernel
#     vhf = mf.get_veff(mol, dm, dm_last, vhf)
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/dft/rks.py", line 80, in get_veff
#     n, exc, vxc = ni.nr_rks(mol, ks.grids, ks.xc, dm, max_memory=max_memory)
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/dft/numint.py", line 923, in nr_rks
#     for i, rho, ao, mask, weight, vxc in block_loop(ao_deriv):
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/dft/numint.py", line 900, in block_loop
#     exc, vxc = ni.eval_xc(xc_code, rho, spin=0,
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/dft/numint.py", line 2576, in eval_xc
#     return self.libxc.eval_xc(xc_code, rho, spin, relativity, deriv,
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/dft/xcfun.py", line 516, in eval_xc
#     return _eval_xc(hyb, fn_facs, rho, spin, relativity, deriv, verbose)
#   File "/Users/yangjunjie/opt/pyscf-main/pyscf/dft/xcfun.py", line 876, in _eval_xc
#     _itrf.XCFUN_eval_xc(ctypes.c_int(n),
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/yangjunjie/opt/anaconda3/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-2-fe42d1dc821a> in <module>
# ----> 1 dr_list, e_r_list, e_u0_list, e_u1_list = get_r_ene(1.6)
#
# <ipython-input-1-a0a1ae08209f> in get_r_ene(r)
#      72         mf.verbose    = 4
# ---> 73         mf.kernel(dm0 = dm0_rhf)
#      74         dm0_rhf = mf.make_rdm1()
#
# ~/opt/pyscf-main/pyscf/lib/misc.py in aliased_fn(self, *args, **kwargs)
#     637     def aliased_fn(self, *args, **kwargs):
# --> 638         return getattr(self, fname)(*args, **kwargs)
#     639
#
# ~/opt/pyscf-main/pyscf/scf/hf.py in scf(self, dm0, **kwargs)
#    1668                     self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 1669                     kernel(self, self.conv_tol, self.conv_tol_grad,
#    1670                            dm0=dm0, callback=self.callback,
#
# ~/opt/pyscf-main/pyscf/scf/hf.py in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     177         dm = lib.tag_array(dm, mo_coeff=mo_coeff, mo_occ=mo_occ)
# --> 178         vhf = mf.get_veff(mol, dm, dm_last, vhf)
#     179         e_tot = mf.energy_tot(dm, h1e, vhf)
#
# ~/opt/pyscf-main/pyscf/dft/rks.py in get_veff(ks, mol, dm, dm_last, vhf_last, hermi)
#      79         max_memory = ks.max_memory - lib.current_memory()[0]
# ---> 80         n, exc, vxc = ni.nr_rks(mol, ks.grids, ks.xc, dm, max_memory=max_memory)
#      81         if ks.nlc:
#
# ~/opt/pyscf-main/pyscf/dft/numint.py in nr_rks(ni, mol, grids, xc_code, dms, relativity, hermi, max_memory, verbose)
#     922         ao_deriv = 1
# --> 923         for i, rho, ao, mask, weight, vxc in block_loop(ao_deriv):
#     924             wv = _rks_gga_wv0(rho, vxc, weight)
#
# ~/opt/pyscf-main/pyscf/dft/numint.py in block_loop(ao_deriv)
#     899                 rho = make_rho(i, ao, mask, xctype)
# --> 900                 exc, vxc = ni.eval_xc(xc_code, rho, spin=0,
#     901                                       relativity=relativity, deriv=1,
#
# ~/opt/pyscf-main/pyscf/dft/numint.py in eval_xc(self, xc_code, rho, spin, relativity, deriv, omega, verbose)
#    2575         if omega is None: omega = self.omega
# -> 2576         return self.libxc.eval_xc(xc_code, rho, spin, relativity, deriv,
#    2577                                   omega, verbose)
#
# ~/opt/pyscf-main/pyscf/dft/xcfun.py in eval_xc(xc_code, rho, spin, relativity, deriv, omega, verbose)
#     515         hyb[2] = float(omega)
# --> 516     return _eval_xc(hyb, fn_facs, rho, spin, relativity, deriv, verbose)
#     517
#
# ~/opt/pyscf-main/pyscf/dft/xcfun.py in _eval_xc(hyb, fn_facs, rho, spin, relativity, deriv, verbose)
#     875     if n > 0:
# --> 876         _itrf.XCFUN_eval_xc(ctypes.c_int(n),
#     877                             (ctypes.c_int*n)(*fn_ids),
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
from matplotlib import pyplot

fig, ax = pyplot.subplots()
ax.plot(dr_list, e_r_list - e_r_list[11])
ax.plot(dr_list, e_u0_list - e_u0_list[11])
ax.plot(dr_list, e_u1_list - e_u1_list[11])

ax.set_xlim(-0.06, 0.06)
ax.set_ylim(-0.01, 0.01)

# %%
from matplotlib import pyplot

dr_list, e_r_list, e_u0_list, e_u1_list = get_r_ene(1.2)

fig, ax = pyplot.subplots()
ax.plot(dr_list, e_r_list - e_r_list[11])
ax.plot(dr_list, e_u0_list - e_u0_list[11])
ax.plot(dr_list, e_u1_list - e_u1_list[11])

ax.set_xlim(-0.06, 0.06)
ax.set_ylim(-0.01, 0.01)

# %%
from matplotlib import pyplot

fig, ax = pyplot.subplots()
ax.plot(dr_list, e_r_list - e_r_list[11])
# ax.plot(dr_list, e_cas_list - e_cas_list[11])
# ax.plot(dr_list, [e[1] for e in e_cas_list])
ax.plot(dr_list, e_u0_list - e_u0_list[11])
ax.plot(dr_list, e_u1_list - e_u1_list[11])

ax.set_xlim(-0.06, 0.06)
ax.set_ylim(-0.01, 0.01)
# ax.set_xlim(-0.02, 0.02)
